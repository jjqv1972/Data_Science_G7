# %% [markdown]
# # UTILIZANDO PANDAS MISSING EXTENSION EN DATASET DE PENGUINS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #EJECUTAMOS NOTEBOOK DE PANDAS MISSING EXTENSION

# %%
# %run '/content/pandas_missing_extension.ipynb'

# %% [markdown]
# # CARGAMOS NUESTRO DATASET

# %%
penguins_df = sns.load_dataset('penguins')
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # TOTAL DE NULOS

# %%
penguins_df.missing.number_missing()
# Out:
# np.int64(19)

# %% [markdown]
# # ANALIZANDO POR VARIABLES FALTANTES(COLUMNAS)

# %%
penguins_df.missing.missing_variable_summary()
# Out:
#             variable  n_missing  n_cases  pct_missing
# 0            species          0      344     0.000000
# 1             island          0      344     0.000000
# 2     bill_length_mm          2      344     0.581395
# 3      bill_depth_mm          2      344     0.581395
# 4  flipper_length_mm          2      344     0.581395
# 5        body_mass_g          2      344     0.581395
# 6                sex         11      344     3.197674

# %%
penguins_df.missing.missing_variable_table()
# Out:
#    n_missing_in_variable  n_variables  pct_variables
# 0                      2            4      57.142857
# 1                      0            2      28.571429
# 2                     11            1      14.285714

# %%
penguins_df.missing.missing_variable_plot()

# %% [markdown]
# # ANALIZANDO POR OBSERVACIONES O CASOS(FILAS)

# %%
penguins_df.missing.missing_case_summary()
# Out:
#      case  n_missing  pct_missing
# 0       0          0     0.000000
# 1       1          0     0.000000
# 2       2          0     0.000000
# 3       3          5    55.555556
# 4       4          0     0.000000
# ..    ...        ...          ...
# 339   339          5    55.555556
# 340   340          0     0.000000
# 341   341          0     0.000000
# 342   342          0     0.000000
# 343   343          0     0.000000
#
# [344 rows x 3 columns]

# %%
penguins_df.missing.missing_case_table()
# Out:
#    n_missing_in_case  n_cases   pct_case
# 0                  0      333  96.802326
# 1                  1        9   2.616279
# 2                  5        2   0.581395

# %%
penguins_df.missing.missing_case_plot()
