# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
X = df.select_dtypes(include=[np.number])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # ALGORITMO PARA ENCONTRAR LOS MEJORES PARAMETROS PARA KMEANS

# %%
import itertools
# Valores a probar
n_clusters_options = range(2, 5)
init_options = ['k-means++', 'random']
max_iter_options = [300, 500]
tol_options = [1e-4,1e-3]
n_init_options = [10, 15]
algorithm_options = ['lloyd', 'elkan']

# %% [markdown]
# # Todas las combinaciones posibles de parámetros

# %%
param_combinations = list(itertools.product(n_clusters_options, init_options, max_iter_options, tol_options, n_init_options, algorithm_options))

best_silhouette = -1
best_params = None
silhouette_scores = {}

# %% [markdown]
# # Probar todas las combinaciones

# %%
for n_clusters, init, max_iter, tol, n_init, algorithm in param_combinations:
    try:
        kmeans = KMeans(
            n_clusters=n_clusters,
            init=init,
            max_iter=max_iter,
            tol=tol,
            n_init=n_init,
            algorithm=algorithm,
            random_state=42
        )
        kmeans.fit(X_scaled)
        labels = kmeans.labels_
        silhouette = silhouette_score(X_scaled, labels)

        if n_clusters not in silhouette_scores:
            silhouette_scores[n_clusters] = []
        silhouette_scores[n_clusters].append(silhouette)

        print(f'n_clusters={n_clusters}, init={init}, max_iter={max_iter}, tol={tol}, n_init={n_init}, algorithm={algorithm} -> Silhouette: {silhouette:.4f}')

        if silhouette > best_silhouette:
            best_silhouette = silhouette
            best_params = (n_clusters, init, max_iter, tol, n_init, algorithm)
    except Exception as e:
        print(f'Error con parámetros n_clusters={n_clusters}, init={init}, max_iter={max_iter}, tol={tol}, n_init={n_init}, algorithm={algorithm}: {e}')
# Out:
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.5818
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.5818
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4594
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4594
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4594
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4594
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4594
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4594
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4594
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4594
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4599
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4599
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3869
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3869
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3866
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3866

# %% [markdown]
# # Mostrar mejor combinación

# %%
print("\nMejores parámetros encontrados:")
print(f'n_clusters={best_params[0]}, init={best_params[1]}, max_iter={best_params[2]}, tol={best_params[3]}, n_init={best_params[4]}, algorithm={best_params[5]} -> Mejor Silhouette: {best_silhouette:.4f}')
# Out:
# Mejores parámetros encontrados:
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Mejor Silhouette: 0.5818
