# %% [markdown]
# # MODELO KMEANS PARA CLASIFICACIÓN DE CLIENTES
# ## FUENTE : [KAGGLE](https://www.kaggle.com/datasets/dev0914sharma/customer-clustering?resource=download)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dev0914sharma/customer-clustering")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/dev0914sharma/customer-clustering/1.archive...
# 100%|██████████| 25.9k/25.9k [00:00<00:00, 13.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/dev0914sharma/customer-clustering/versions/1

# %%
# !ls /root/.cache/kagglehub/datasets/dev0914sharma/customer-clustering/versions/1
# Out:
# 'segmentation data.csv'  'segmentation data legend.xlsx'

# %%
PATH_CSV = path + '/segmentation data.csv'

# %%
df = pd.read_csv(PATH_CSV)
df
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 0                   2
# 1                   2
# 2                   0
# 3                   1
# 4                   1
# ...               ...
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0
#
# [2000 rows x 8 columns]

# %%
df.dtypes
# Out:
# ID                 int64
# Sex                int64
# Marital status     int64
# Age                int64
# Education          int64
# Income             int64
# Occupation         int64
# Settlement size    int64
# dtype: object

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=['ID'],inplace=True)
df.head(5)
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
# 2    0               0   49          1   89210           0                0
# 3    0               0   45          1  171565           1                1
# 4    0               0   53          1  149031           1                1

# %% [markdown]
# # BUSCAMOS OUTLIERS

# %%
from scipy.stats import zscore

z_scores = df.apply(zscore)

outliers = (z_scores.abs() > 3).sum()

outliers
# Out:
# Sex                 0
# Marital status      0
# Age                11
# Education          36
# Income             31
# Occupation          0
# Settlement size     0
# dtype: int64

# %%
plt.figure(figsize=(12,6))

sns.boxplot(data=df[['Age','Education','Income']])
plt.show()

# %%
df_cleaned = df[
    (z_scores['Age'].abs() <= 3) &
    (z_scores['Education'].abs() <= 3) &
    (z_scores['Income'].abs() <= 3)
].copy()
df_cleaned
# Out:
#       Sex  Marital status  Age  Education  Income  Occupation  Settlement size
# 0       0               0   67          2  124670           1                2
# 1       1               1   22          1  150773           1                2
# 2       0               0   49          1   89210           0                0
# 3       0               0   45          1  171565           1                1
# 4       0               0   53          1  149031           1                1
# ...   ...             ...  ...        ...     ...         ...              ...
# 1995    1               0   47          1  123525           0                0
# 1996    1               1   27          1  117744           1                0
# 1997    0               0   31          0   86400           0                0
# 1998    1               1   24          1   97968           0                0
# 1999    0               0   25          0   68416           0                0
#
# [1926 rows x 7 columns]

# %% [markdown]
# # APLICAMOS KMEANS

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X = df_cleaned.select_dtypes(include=[np.number])
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X = df_cleaned.select_dtypes(include=[np.number])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## BUSCAMOS EL NÚMERO OPTIMO DE CLUSTERS USANDO METODO DEL CODO

# %%
from sklearn.cluster import KMeans

inertia = []
k_values = range(1,11)

for k in k_values:
  kmeans = KMeans(n_clusters=k,random_state=42)
  kmeans.fit(X_scaled)
  inertia.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(k_values, inertia, marker='o', linestyle='--')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Inercia')
plt.title('Método del Codo para determinar k óptimo')
plt.show()

# %%
import itertools
# Valores a probar
n_clusters_options = range(2, 15)
init_options = ['k-means++', 'random']
max_iter_options = [300, 500]
tol_options = [1e-4, 1e-5, 1e-3]
n_init_options = [10, 15]
algorithm_options = ['lloyd', 'elkan']

# %%
param_combinations = list(itertools.product(n_clusters_options, init_options, max_iter_options, tol_options, n_init_options, algorithm_options))

best_silhouette = -1
best_params = None
silhouette_scores = {}

# %%
for n_clusters, init, max_iter, tol, n_init, algorithm in param_combinations:
    try:
        kmeans = KMeans(
            n_clusters=n_clusters,
            init=init,
            max_iter=max_iter,
            tol=tol,
            n_init=n_init,
            algorithm=algorithm,
            random_state=42
        )
        kmeans.fit(X_scaled)
        labels = kmeans.labels_
        silhouette = silhouette_score(X_scaled, labels)

        if n_clusters not in silhouette_scores:
            silhouette_scores[n_clusters] = []
        silhouette_scores[n_clusters].append(silhouette)

        print(f'n_clusters={n_clusters}, init={init}, max_iter={max_iter}, tol={tol}, n_init={n_init}, algorithm={algorithm} -> Silhouette: {silhouette:.4f}')

        if silhouette > best_silhouette:
            best_silhouette = silhouette
            best_params = (n_clusters, init, max_iter, tol, n_init, algorithm)
    except Exception as e:
        print(f'Error con parámetros n_clusters={n_clusters}, init={init}, max_iter={max_iter}, tol={tol}, n_init={n_init}, algorithm={algorithm}: {e}')
# Out:
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3733
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3733
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3776
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3776
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3422
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3422
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3839
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3839
# n_clusters=5, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3456
# n_clusters=5, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3456
# n_clusters=5, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3456
# n_clusters=5, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3456
# n_clusters=5, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4042
# n_clusters=5, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4042
# n_clusters=6, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4102
# n_clusters=6, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4102
# n_clusters=7, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3989
# n_clusters=7, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3989
# n_clusters=7, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4074
# n_clusters=7, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4074
# n_clusters=8, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4077
# n_clusters=8, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4077
# n_clusters=8, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4198
# n_clusters=8, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4198
# n_clusters=9, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4010
# n_clusters=9, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4010
# n_clusters=9, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3948
# n_clusters=9, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3948
# n_clusters=10, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4028
# n_clusters=10, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4028
# n_clusters=10, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.3990
# n_clusters=10, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.3990
# n_clusters=11, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4203
# n_clusters=11, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4203
# n_clusters=11, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4203
# n_clusters=11, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4203
# n_clusters=11, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4205
# n_clusters=11, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4205
# n_clusters=11, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4203
# n_clusters=11, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4203
# n_clusters=11, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4203
# n_clusters=11, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4203
# n_clusters=11, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4002
# n_clusters=11, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4205
# n_clusters=11, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4205
# n_clusters=11, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4044
# ...
# n_clusters=11, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4044
# n_clusters=11, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4044
# n_clusters=12, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4236
# n_clusters=12, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4236
# n_clusters=12, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4086
# n_clusters=12, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4086
# n_clusters=13, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4367
# n_clusters=13, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4367
# n_clusters=13, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4367
# n_clusters=13, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4367
# n_clusters=13, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4367
# n_clusters=13, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4367
# n_clusters=13, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4367
# n_clusters=13, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4367
# n_clusters=13, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4367
# n_clusters=13, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4367
# n_clusters=13, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4434
# n_clusters=13, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4367
# n_clusters=13, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4367
# n_clusters=13, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4217
# n_clusters=13, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4217
# n_clusters=13, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4217
# n_clusters=13, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4217
# n_clusters=13, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4217
# n_clusters=13, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4217
# n_clusters=13, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4217
# n_clusters=13, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4217
# n_clusters=13, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4217
# n_clusters=13, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4217
# n_clusters=13, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4249
# n_clusters=13, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4217
# n_clusters=13, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4217
# n_clusters=14, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4609
# n_clusters=14, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4609
# n_clusters=14, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4354
# n_clusters=14, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4354
# n_clusters=14, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=300, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4354
# n_clusters=14, init=random, max_iter=300, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4354
# n_clusters=14, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4354
# n_clusters=14, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4354
# n_clusters=14, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.4354
# n_clusters=14, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.4354
# n_clusters=14, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=lloyd -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=500, tol=1e-05, n_init=10, algorithm=elkan -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=lloyd -> Silhouette: 0.4354
# n_clusters=14, init=random, max_iter=500, tol=1e-05, n_init=15, algorithm=elkan -> Silhouette: 0.4354
# n_clusters=14, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.4391
# n_clusters=14, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.4354
# n_clusters=14, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.4354

# %%
print("\nMejores parámetros encontrados:")
print(f'n_clusters={best_params[0]}, init={best_params[1]}, max_iter={best_params[2]}, tol={best_params[3]}, n_init={best_params[4]}, algorithm={best_params[5]} -> Mejor Silhouette: {best_silhouette:.4f}')
# Out:
# Mejores parámetros encontrados:
# n_clusters=14, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Mejor Silhouette: 0.4609
