# %% [markdown]
# # MODELO KMEANS PARA CLASIFICACIÓN DE CLIENTES
# ## FUENTE : [KAGGLE](https://www.kaggle.com/datasets/dev0914sharma/customer-clustering?resource=download)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dev0914sharma/customer-clustering")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/dev0914sharma/customer-clustering/1.archive...
# 100%|██████████| 25.9k/25.9k [00:00<00:00, 27.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/dev0914sharma/customer-clustering/versions/1

# %%
# !ls /root/.cache/kagglehub/datasets/dev0914sharma/customer-clustering/versions/1
# Out:
# 'segmentation data.csv'  'segmentation data legend.xlsx'

# %%
PATH_CSV = path + '/segmentation data.csv'

# %%
df = pd.read_csv(PATH_CSV)
df
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 0                   2
# 1                   2
# 2                   0
# 3                   1
# 4                   1
# ...               ...
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0
#
# [2000 rows x 8 columns]

# %%
df.dtypes
# Out:
# ID                 int64
# Sex                int64
# Marital status     int64
# Age                int64
# Education          int64
# Income             int64
# Occupation         int64
# Settlement size    int64
# dtype: object

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df_cleaned = df.copy()
df_cleaned.drop(columns=['ID'],inplace=True)
df_cleaned.head(5)
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
# 2    0               0   49          1   89210           0                0
# 3    0               0   45          1  171565           1                1
# 4    0               0   53          1  149031           1                1

# %% [markdown]
# # APLICAMOS KMEANS

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
X = df_cleaned.select_dtypes(include=[np.number])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
import itertools
# Valores a probar
n_clusters_options = range(2, 5)
init_options = ['k-means++', 'random']
max_iter_options = [300, 500]
tol_options = [1e-4,1e-3]
n_init_options = [10, 15]
algorithm_options = ['lloyd', 'elkan']

# %%
param_combinations = list(itertools.product(n_clusters_options, init_options, max_iter_options, tol_options, n_init_options, algorithm_options))

best_silhouette = -1
best_params = None
silhouette_scores = {}

# %%
for n_clusters, init, max_iter, tol, n_init, algorithm in param_combinations:
    try:
        kmeans = KMeans(
            n_clusters=n_clusters,
            init=init,
            max_iter=max_iter,
            tol=tol,
            n_init=n_init,
            algorithm=algorithm,
            random_state=42
        )
        kmeans.fit(X_scaled)
        labels = kmeans.labels_
        silhouette = silhouette_score(X_scaled, labels)

        if n_clusters not in silhouette_scores:
            silhouette_scores[n_clusters] = []
        silhouette_scores[n_clusters].append(silhouette)

        print(f'n_clusters={n_clusters}, init={init}, max_iter={max_iter}, tol={tol}, n_init={n_init}, algorithm={algorithm} -> Silhouette: {silhouette:.4f}')

        if silhouette > best_silhouette:
            best_silhouette = silhouette
            best_params = (n_clusters, init, max_iter, tol, n_init, algorithm)
    except Exception as e:
        print(f'Error con parámetros n_clusters={n_clusters}, init={init}, max_iter={max_iter}, tol={tol}, n_init={n_init}, algorithm={algorithm}: {e}')
# Out:
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2498
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2498
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2498
# n_clusters=2, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2498
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2481
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2481
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2507
# n_clusters=2, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2507
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2498
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2498
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2498
# n_clusters=2, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2498
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2481
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2481
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2507
# n_clusters=2, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2507
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2482
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2482
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2482
# n_clusters=2, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2482
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2507
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2507
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2507
# n_clusters=2, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2507
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2482
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2482
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2482
# n_clusters=2, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2482
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2507
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2507
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2507
# n_clusters=2, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2507
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2712
# n_clusters=3, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2712
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2718
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2718
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2718
# n_clusters=3, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2718
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2719
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2719
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2719
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2719
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2718
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2718
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2718
# n_clusters=3, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2718
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2719
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2719
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2719
# n_clusters=3, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2719
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2688
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2688
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2688
# n_clusters=4, init=k-means++, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2688
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2686
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2686
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2688
# n_clusters=4, init=k-means++, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2688
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2688
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2688
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2688
# n_clusters=4, init=k-means++, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2688
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2686
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2686
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2688
# n_clusters=4, init=k-means++, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2688
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=300, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=300, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=lloyd -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=10, algorithm=elkan -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=lloyd -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=500, tol=0.0001, n_init=15, algorithm=elkan -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=lloyd -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=10, algorithm=elkan -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=lloyd -> Silhouette: 0.2686
# n_clusters=4, init=random, max_iter=500, tol=0.001, n_init=15, algorithm=elkan -> Silhouette: 0.2686

# %%
print("\nMejores parámetros encontrados:")
print(f'n_clusters={best_params[0]}, init={best_params[1]}, max_iter={best_params[2]}, tol={best_params[3]}, n_init={best_params[4]}, algorithm={best_params[5]} -> Mejor Silhouette: {best_silhouette:.4f}')
# Out:
# Mejores parámetros encontrados:
# n_clusters=3, init=random, max_iter=300, tol=0.001, n_init=10, algorithm=lloyd -> Mejor Silhouette: 0.2719

# %%
k = 3
kmeans = KMeans(n_clusters=k,init='random', max_iter=300, tol=0.001, n_init=10, algorithm='lloyd')
kmeans.fit(X_scaled)
labels = kmeans.labels_
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroides')
plt.xlabel('Característica 1 (escalada)')
plt.ylabel('Característica 2 (escalada)')
plt.title(f'Clusters con KMeans (k={k})')
plt.legend()
plt.show()
silhouette_value = silhouette_score(X_scaled,labels)
print(f'Coeficiente de Silueta para k={k} : {silhouette_value}:.4f')
# Out:
# Coeficiente de Silueta para k=3 : 0.26478110876466865:.4f
