# %% [markdown]
# # EJEMPLO BASICO DE MODELOS DE ARBOLES DE DECISIÓN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_df = sns.load_dataset('titanic')
titanic_df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %% [markdown]
# # EDA

# %%
columns_to_drop = ['fare','embarked','class','who','adult_male','deck','embark_town','alive','alone']
titanic_df.drop(columns_to_drop,axis='columns',inplace=True)
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch
# 0           0       3    male  22.0      1      0
# 1           1       1  female  38.0      1      0
# 2           1       3  female  26.0      0      0
# 3           1       1  female  35.0      1      0
# 4           0       3    male  35.0      0      0
# ..        ...     ...     ...   ...    ...    ...
# 886         0       2    male  27.0      0      0
# 887         1       1  female  19.0      0      0
# 888         0       3  female   NaN      1      2
# 889         1       1    male  26.0      0      0
# 890         0       3    male  32.0      0      0
#
# [891 rows x 6 columns]

# %% [markdown]
# # ANALIZAMOS NULOS

# %%
titanic_df.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# sibsp         0
# parch         0
# dtype: int64

# %%
titanic_df.dropna(inplace=True)

# %% [markdown]
# # CODIFICACIÓN DE VARIABLES CATEGORICAS

# %%
titanic_df.dtypes
# Out:
# survived      int64
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# dtype: object

# %%
titanic_df = pd.get_dummies(titanic_df,columns=['sex'],drop_first=True)
titanic_df.head()
# Out:
#    survived  pclass   age  sibsp  parch  sex_male
# 0         0       3  22.0      1      0      True
# 1         1       1  38.0      1      0     False
# 2         1       3  26.0      0      0     False
# 3         1       1  35.0      1      0     False
# 4         0       3  35.0      0      0      True

# %%
titanic_df['sex_male'] = titanic_df['sex_male'].astype(int)
titanic_df.rename(columns = {'sex_male':'sex'},inplace=True)
titanic_df.head(10)
# Out:
#     survived  pclass   age  sibsp  parch  sex
# 0          0       3  22.0      1      0    1
# 1          1       1  38.0      1      0    0
# 2          1       3  26.0      0      0    0
# 3          1       1  35.0      1      0    0
# 4          0       3  35.0      0      0    1
# 6          0       1  54.0      0      0    1
# 7          0       3   2.0      3      1    1
# 8          1       3  27.0      0      2    0
# 9          1       2  14.0      1      0    0
# 10         1       3   4.0      1      1    0

# %%
titanic_df.dtypes
# Out:
# survived      int64
# pclass        int64
# age         float64
# sibsp         int64
# parch         int64
# sex           int64
# dtype: object

# %% [markdown]
# # ENTRENAMIENTO DE MODELO DE ARBOL DE DECISIÓN

# %% [markdown]
# # PASO 1 - DEFINIMOS VARIABLES INDEPENDIENTES(X) Y DEPENDIENTES (Y)

# %%
X = titanic_df.drop('survived',axis=1)
y = titanic_df['survived']

# %% [markdown]
# # PASO 2 - CREAMOS EL MODELO DE ARBOL DE DECISIÓN

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %% [markdown]
# # PASO 3 - DIVIDIR DATASET EN ENTRENAMIENTO Y PRUEBA

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=00000)

# %% [markdown]
# # **NOTA: EN EL CASO DE ARBOLES DE DECISIÓN NO HAY ESCALAMIENTO DE VARIABLES**

# %% [markdown]
# # PASO 4 - ENTRENAMOS EL MODELO

# %%
tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # PASO 5 - EVALUAMOS EL MODELO

# %%
from sklearn.metrics import accuracy_score

y_pred = tree.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(f'Precisión del modelo: {accuracy}')
# Out:
# Precisión del modelo: 0.7692307692307693

# %%
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['No sobrevivió', 'Sobrevivió'], yticklabels=['No sobrevivió', 'Sobrevivió'])
plt.xlabel('Predicho')
plt.ylabel('Real')
plt.title('Matriz de Confusión')
plt.show()

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
plot_tree(tree, filled=True, feature_names=X_train.columns.tolist(), class_names=[str(x) for x in y_train.unique()], rounded=True)
plt.title("Árbol de Decisión del Modelo Titanic")
plt.show()
