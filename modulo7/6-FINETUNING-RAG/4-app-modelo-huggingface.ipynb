# %%
from transformers import pipeline

pipe = pipeline("text-classification", model="cesarcodigo/modelo_sentimiento_peruano")
# Out:
# config.json:   0%|          | 0.00/996 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/439M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/736k [00:00<?, ?B/s]

# %%
texto = 'Esta peli esta buenaza'
respuesta = pipe(texto)
print(respuesta)
# Out:
# [{'label': 'positive', 'score': 0.9140321016311646}]

# %% [markdown]
# #CREAMOS APP CON GRADIO PARA EXPONER EL MODELO

# %%
def analisis_sentimiento(texto):
  resultado = pipe(texto)[0]
  label = resultado['label']
  score = resultado['score']

  if label == 'positive':
    label = 'Positivo'
  else:
    label = 'Negativo'

  return f'Tú comentario  es {label} (score : {round(score, 4)})'

# %%
print(analisis_sentimiento(texto))
# Out:
# Este texto es Positivo (score : 0.914)

# %%
import gradio as gr

demo = gr.Interface(
    fn=analisis_sentimiento,
    inputs=gr.Textbox(label='coloca tu comentario'),
    outputs=gr.Textbox(label='Resultado')
)
demo.launch(
    share=True
)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://692cc2cdc703c00fcb.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://692cc2cdc703c00fcb.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
