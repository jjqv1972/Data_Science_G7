# %% [markdown]
# # FUNCIONES DE AGRUPACIÓN

# %%
import pandas as pd
df_books = pd.read_csv('https://github.com/cesarmayta/datasets/raw/refs/heads/main/libros.csv')
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# # SQL : select Author,sum(*) from libros group by Author

# %%
df_books.groupby('Author').sum().reset_index()
# Out:
#                          Author  \
# 0              Abraham Verghese
# 1                Adam Gasiewski
# 2                 Adam Mansbach
# 3                     Adir Levy
# 4    Admiral William H. McRaven
# ..                          ...
# 243             Walter Isaacson
# 244               William Davis
# 245            William P. Young
# 246            Wizards RPG Team
# 247                Zhi Gang Sha
#
#                                                   Name  User Rating  Reviews  \
# 0                   Cutting for StoneCutting for Stone          9.2     9732
# 1    Milk and Vine: Inspirational Quotes From Class...          4.4     3113
# 2                                 Go the F**k to Sleep          4.8     9568
# 3    What Should Danny Do? (The Power to Choose Ser...          4.8     8170
# 4    Make Your Bed: Little Things That Can Change Y...          4.7    10199
# ..                                                 ...          ...      ...
# ...

# %%
df_books.groupby('Author')[['Reviews','Price']].sum().reset_index()
# Out:
#                          Author  Reviews  Price
# 0              Abraham Verghese     9732     22
# 1                Adam Gasiewski     3113      6
# 2                 Adam Mansbach     9568      9
# 3                     Adir Levy     8170     13
# 4    Admiral William H. McRaven    10199     11
# ..                          ...      ...    ...
# 243             Walter Isaacson    18668     61
# 244               William Davis    14994     12
# 245            William P. Young    39440     16
# 246            Wizards RPG Team    50970     81
# 247                Zhi Gang Sha      257     23
#
# [248 rows x 3 columns]

# %%
df_books.groupby('Author')[['User Rating','Reviews','Price']].mean().reset_index()
# Out:
#                          Author  User Rating       Reviews      Price
# 0              Abraham Verghese     4.600000   4866.000000  11.000000
# 1                Adam Gasiewski     4.400000   3113.000000   6.000000
# 2                 Adam Mansbach     4.800000   9568.000000   9.000000
# 3                     Adir Levy     4.800000   8170.000000  13.000000
# 4    Admiral William H. McRaven     4.700000  10199.000000  11.000000
# ..                          ...          ...           ...        ...
# 243             Walter Isaacson     4.566667   6222.666667  20.333333
# 244               William Davis     4.400000   7497.000000   6.000000
# 245            William P. Young     4.600000  19720.000000   8.000000
# 246            Wizards RPG Team     4.800000  16990.000000  27.000000
# 247                Zhi Gang Sha     4.600000    128.500000  11.500000
#
# [248 rows x 4 columns]

# %% [markdown]
# ## AGREGACIONES

# %%
cols = ['User Rating','Reviews','Price']

# %%
df_books.groupby('Author')[cols].agg(['min','max'])
# Out:
#                            User Rating      Reviews        Price
#                                    min  max     min    max   min max
# Author
# Abraham Verghese                   4.6  4.6    4866   4866    11  11
# Adam Gasiewski                     4.4  4.4    3113   3113     6   6
# Adam Mansbach                      4.8  4.8    9568   9568     9   9
# Adir Levy                          4.8  4.8    8170   8170    13  13
# Admiral William H. McRaven         4.7  4.7   10199  10199    11  11
# ...                                ...  ...     ...    ...   ...  ..
# Walter Isaacson                    4.5  4.6    3014   7827    20  21
# William Davis                      4.4  4.4    7497   7497     6   6
# William P. Young                   4.6  4.6   19720  19720     8   8
# Wizards RPG Team                   4.8  4.8   16990  16990    27  27
# Zhi Gang Sha                       4.6  4.6      37    220     6  17
#
# [248 rows x 6 columns]

# %%
df_books.groupby('Author')[cols].agg({'Reviews':['min','max'],'User Rating':'sum','Price':'mean'}).reset_index()
# Out:
#                          Author Reviews        User Rating      Price
#                                     min    max         sum       mean
# 0              Abraham Verghese    4866   4866         9.2  11.000000
# 1                Adam Gasiewski    3113   3113         4.4   6.000000
# 2                 Adam Mansbach    9568   9568         4.8   9.000000
# 3                     Adir Levy    8170   8170         4.8  13.000000
# 4    Admiral William H. McRaven   10199  10199         4.7  11.000000
# ..                          ...     ...    ...         ...        ...
# 243             Walter Isaacson    3014   7827        13.7  20.333333
# 244               William Davis    7497   7497         8.8   6.000000
# 245            William P. Young   19720  19720         9.2   8.000000
# 246            Wizards RPG Team   16990  16990        14.4  27.000000
# 247                Zhi Gang Sha      37    220         9.2  11.500000
#
# [248 rows x 5 columns]

# %%
df_books.groupby('Author')[cols].agg(rating_maximo=('User Rating','max'),precio_promedio=('Price','mean')).reset_index()
# Out:
#                          Author  rating_maximo  precio_promedio
# 0              Abraham Verghese            4.6        11.000000
# 1                Adam Gasiewski            4.4         6.000000
# 2                 Adam Mansbach            4.8         9.000000
# 3                     Adir Levy            4.8        13.000000
# 4    Admiral William H. McRaven            4.7        11.000000
# ..                          ...            ...              ...
# 243             Walter Isaacson            4.6        20.333333
# 244               William Davis            4.4         6.000000
# 245            William P. Young            4.6         8.000000
# 246            Wizards RPG Team            4.8        27.000000
# 247                Zhi Gang Sha            4.6        11.500000
#
# [248 rows x 3 columns]

# %% [markdown]
# # AGRUPACIÓN POR 2 COLUMNAS

# %%
df_books.groupby(['Year','Genre'])[cols].count().reset_index()
# Out:
#     Year        Genre  User Rating  Reviews  Price
# 0   2009      Fiction           24       24     24
# 1   2009  Non Fiction           26       26     26
# 2   2010      Fiction           20       20     20
# 3   2010  Non Fiction           30       30     30
# 4   2011      Fiction           21       21     21
# 5   2011  Non Fiction           29       29     29
# 6   2012      Fiction           21       21     21
# 7   2012  Non Fiction           29       29     29
# 8   2013      Fiction           24       24     24
# 9   2013  Non Fiction           26       26     26
# 10  2014      Fiction           29       29     29
# 11  2014  Non Fiction           21       21     21
# 12  2015      Fiction           17       17     17
# 13  2015  Non Fiction           33       33     33
# 14  2016      Fiction           19       19     19
# 15  2016  Non Fiction           31       31     31
# 16  2017      Fiction           24       24     24
# ...
