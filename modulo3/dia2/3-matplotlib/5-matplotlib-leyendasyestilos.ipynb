# %% [markdown]
# # LEYENDAS CON MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,5,11)
y = np.sin(x)

# %% [markdown]
# ## NOTA : PARA QUE SE MUESTREN LAS LEYENDAS SE DEBE LLAMAR A ESTA FUNCIÓN plt.legend()

# %%
plt.plot(x,y,label='sin(x)')
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.title('Gráfica de sin(x)')

plt.legend()
plt.show()

# %% [markdown]
# # ARRAYS DE SUBPLOTS CON LEYENDAS

# %%
fig,axes = plt.subplots(1,2,figsize=(5,5))

axes[0].plot(x,y,label='sin(x)')
axes[0].set_title('sin(x)')
axes[0].set_xlabel('Variable X')
axes[0].set_ylabel('Variable Y')
axes[0].legend()

axes[1].plot(y,x,label='Relación y x')
axes[1].set_title('yx')
axes[1].set_xlabel('Variable Y')
axes[1].set_ylabel('Variable X')
axes[1].legend()

fig.tight_layout()

plt.show()

# %% [markdown]
# # ESTILOS

# %%
x = np.linspace(0,5,11)

# %% [markdown]
# # PARA VER LOS ESTILOS DISPONIBLES EN PYPLOT

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('dark_background')

# %%
fig,axes = plt.subplots(figsize=(8,8))
axes.plot(x,x**2,'r--')
fig.show()

# %%
fig,axes = plt.subplots(figsize=(8,8))
axes.plot(x,x+1,color='#15B01A',linestyle=':',marker='x',linewidth=5)
axes.plot(x,x+2,color='red',linestyle='--',marker='8',linewidth=9)
axes.plot(x,x+3,color='yellow',linestyle='dashed',marker='x',linewidth=3)
axes.plot(x,x+4,color='pink',linestyle='-',marker='x',linewidth=2)
fig.show()
