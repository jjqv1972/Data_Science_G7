# %% [markdown]
# **Alumno:** Javier José Quispe Varillas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

penguins = sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
# Eliminar filas con valores nulos
penguins = penguins.dropna().reset_index(drop=True)

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 328  Gentoo     Biscoe            47.2           13.7              214.0
# 329  Gentoo     Biscoe            46.8           14.3              215.0
# 330  Gentoo     Biscoe            50.4           15.7              222.0
# 331  Gentoo     Biscoe            45.2           14.8              212.0
# 332  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3         3450.0  Female
# 4         3650.0    Male
# ..           ...     ...
# 328       4925.0  Female
# 329       4850.0  Female
# 330       5750.0    Male
# 331       5200.0  Female
# 332       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## 🧩 Ejercicio 1 – Cálculos con NumPy (25%)
#
# 1. A partir de la columna `body_mass_g`, crea un arreglo de NumPy llamado `mass_array`.
# 2. Calcula e imprime:
#    - La **media** del peso corporal (`body_mass_g`).
#    - La **mediana** del peso corporal.
#    - El **mínimo** y **máximo** del peso corporal.

# %%
arr = np.array(penguins['body_mass_g'])
arr
# Out:
# array([3750., 3800., 3250., 3450., 3650., 3625., 4675., 3200., 3800.,
#        4400., 3700., 3450., 4500., 3325., 4200., 3400., 3600., 3800.,
#        3950., 3800., 3800., 3550., 3200., 3150., 3950., 3250., 3900.,
#        3300., 3900., 3325., 4150., 3950., 3550., 3300., 4650., 3150.,
#        3900., 3100., 4400., 3000., 4600., 3425., 3450., 4150., 3500.,
#        4300., 3450., 4050., 2900., 3700., 3550., 3800., 2850., 3750.,
#        3150., 4400., 3600., 4050., 2850., 3950., 3350., 4100., 3050.,
#        4450., 3600., 3900., 3550., 4150., 3700., 4250., 3700., 3900.,
#        3550., 4000., 3200., 4700., 3800., 4200., 3350., 3550., 3800.,
#        3500., 3950., 3600., 3550., 4300., 3400., 4450., 3300., 4300.,
#        3700., 4350., 2900., 4100., 3725., 4725., 3075., 4250., 2925.,
#        3550., 3750., 3900., 3175., 4775., 3825., 4600., 3200., 4275.,
#        3900., 4075., 2900., 3775., 3350., 3325., 3150., 3500., 3450.,
#        3875., 3050., 4000., 3275., 4300., 3050., 4000., 3325., 3500.,
#        3500., 4475., 3425., 3900., 3175., 3975., 3400., 4250., 3400.,
#        3475., 3050., 3725., 3000., 3650., 4250., 3475., 3450., 3750.,
#        3700., 4000., 3500., 3900., 3650., 3525., 3725., 3950., 3250.,
#        3750., 4150., 3700., 3800., 3775., 3700., 4050., 3575., 4050.,
#        3300., 3700., 3450., 4400., 3600., 3400., 2900., 3800., 3300.,
#        4150., 3400., 3800., 3700., 4550., 3200., 4300., 3350., 4100.,
#        3600., 3900., 3850., 4800., 2700., 4500., 3950., 3650., 3550.,
#        3500., 3675., 4450., 3400., 4300., 3250., 3675., 3325., 3950.,
#        3600., 4050., 3350., 3450., 3250., 4050., 3800., 3525., 3950.,
#        3650., 3650., 4000., 3400., 3775., 4100., 3775., 4500., 5700.,
#        4450., 5700., 5400., 4550., 4800., 5200., 4400., 5150., 4650.,
#        5550., 4650., 5850., 4200., 5850., 4150., 6300., 4800., 5350.,
#        5700., 5000., 4400., 5050., 5000., 5100., 5650., 4600., 5550.,
#        5250., 4700., 5050., 6050., 5150., 5400., 4950., 5250., 4350.,
#        5350., 3950., 5700., 4300., 4750., 5550., 4900., 4200., 5400.,
#        5100., 5300., 4850., 5300., 4400., 5000., 4900., 5050., 4300.,
#        5000., 4450., 5550., 4200., 5300., 4400., 5650., 4700., 5700.,
#        5800., 4700., 5550., 4750., 5000., 5100., 5200., 4700., 5800.,
#        4600., 6000., 4750., 5950., 4625., 5450., 4725., 5350., 4750.,
#        5600., 4600., 5300., 4875., 5550., 4950., 5400., 4750., 5650.,
#        4850., 5200., 4925., 4875., 4625., 5250., 4850., 5600., 4975.,
#        5500., 5500., 4700., 5500., 4575., 5500., 5000., 5950., 4650.,
#        5500., 4375., 5850., 6000., 4925., 4850., 5750., 5200., 5400.])

# %%
# La media del perso corporal
print(f'La media del peso corporal es: {np.mean(arr)}')
# La mediana del peso corporal
print(f'La mediana del peso corporal es: {np.median(arr)}')
# El minimo y maximo del peso corporal
print(f'El minimo del peso corporal es: {np.min(arr)}')
print(f'El maximo del peso corporal es: {np.max(arr)}')
# Out:
# La media del peso corporal es: 4207.057057057057
# La mediana del peso corporal es: 4050.0
# El minimo del peso corporal es: 2700.0
# El maximo del peso corporal es: 6300.0

# %% [markdown]
# ## 📊 Ejercicio 2 – Agrupaciones y sumatorias con Pandas (25%)
#
# Usando **pandas**, realiza lo siguiente:
#
# 1. Agrupa el DataFrame `penguins` por la columna `species`.
# 2. Calcula para cada especie:
#    - La **suma total** del peso corporal (`body_mass_g`).
#    - El **número de individuos** (conteo de filas).
# 3. Guarda el resultado en un DataFrame llamado `resumen_species` con las columnas:
#    - `total_mass`
#    - `count_penguins`
# 4. Ordena `resumen_species` de mayor a menor según `total_mass` y muéstralo.
#
# ---

# %%
# 1. Agrupa el DataFrame `penguins` por la columna `species`.
df_pen_agru = penguins.groupby('species')

# %%
#  2. Calcula para cada especie:
#  - La suma total del peso corporal (body_mass_g).
df_pen_agru['body_mass_g'].sum()
# Out:
# species
# Adelie       541100.0
# Chinstrap    253850.0
# Gentoo       606000.0
# Name: body_mass_g, dtype: float64

# %%
#  - El número de individuos (conteo de filas).
df_pen_agru['body_mass_g'].count()
# Out:
# species
# Adelie       146
# Chinstrap     68
# Gentoo       119
# Name: body_mass_g, dtype: int64

# %%
# 3 . Guarda el resultado en un DataFrame llamado resumen_species con las columnas:
# - total_mass
# - count_penguins
resumen_species = pd.DataFrame()
resumen_species['total_mass'] = df_pen_agru['body_mass_g'].sum()
resumen_species['count_penguins'] = df_pen_agru['body_mass_g'].count()
resumen_species
# Out:
#            total_mass  count_penguins
# species
# Adelie       541100.0             146
# Chinstrap    253850.0              68
# Gentoo       606000.0             119

# %% [markdown]
# ## 📈 Ejercicio 3 – Visualización con Matplotlib (25%)
#
# Usando el DataFrame `resumen_species` del ejercicio anterior:
#
# 1. Crea un **gráfico de barras** con **Matplotlib** donde:
#    - El eje X sea la **especie**.
#    - El eje Y sea la **suma total de masa corporal (`total_mass`)**.
# 2. Agrega:
#    - Un **título** descriptivo.
#    - Nombres a los ejes: `"Especie"` (X) y `"Suma total de masa corporal (g)"` (Y).
# ---

# %%
# 1. Crea un gráfico de barras con Matplotlib donde:
# - El eje X sea la especie.
# - El eje Y sea la suma total de masa corporal (total_mass).
plt.bar(resumen_species.index, resumen_species['total_mass'])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## 🌈 Ejercicio 4 – Scatterplot con Seaborn (25%)
#
# Usando **seaborn** y el DataFrame `penguins`:
#
# 1. Crea un **diagrama de dispersión (scatterplot)** donde:
#    - Eje X → `bill_length_mm`
#    - Eje Y → `bill_depth_mm`
# 2. El color (`hue`) debe representar la **especie (`species`)**.
# 3. El estilo o forma de los puntos (`style`) debe representar el **sexo (`sex`)

# %%
# 1. Crea un diagrama de dispersión (scatterplot) donde:
# - Eje X → bill_length_mm
# - Eje Y → bill_depth_mm
# 2. El color (hue) debe representar la especie (species).
# 3. El estilo o forma de los puntos (style) debe representar el **sexo (sex)
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species', style='sex')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>
