# %% [markdown]
# ## 🔵 ¿Qué es `scatterplot` en Seaborn?
#
# `scatterplot` es una función de Seaborn que se utiliza para crear **gráficos de dispersión** (también llamados **gráficos de puntos**), mostrando la **relación entre dos variables numéricas**.
#
# Cada punto en el gráfico representa una observación en el conjunto de datos.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip')
plt.show()

# %% [markdown]
# # RELACIÓN DENTRE EL TOTAL DE LA CUENTA Y LA PROPINA

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size')
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day", palette="pastel")
plt.title("Propinas por día con paleta pastel")
plt.show()

# %%
sns.scatterplot(
    data=tips,
    x="total_bill",
    y="tip",
    hue="sex",
    style="smoker",
    size="size",
    alpha=0.6,
    palette="muted"
)
plt.title("Propina vs Total con múltiples dimensiones")
plt.show()

# %% [markdown]
# ### ⚙️ Principales parámetros de `sns.scatterplot`
#
# - `x`:
#   Variable numérica que se asigna al eje **horizontal** (eje X).
#
# - `y`:
#   Variable numérica que se asigna al eje **vertical** (eje Y).
#
# - `hue`:
#   Variable categórica o numérica que determina el **color** de los puntos.
#   Útil para diferenciar grupos o categorías.
#
# - `style`:
#   Variable categórica que define la **forma (símbolo)** de los puntos, como círculos, triángulos, etc.
#
# - `size`:
#   Variable numérica que controla el **tamaño** de cada punto.
#   Sirve para representar una tercera dimensión numérica.
#
# - `alpha`:
#   Nivel de **transparencia** de los puntos (entre `0` y `1`).
#   Útil cuando hay muchos datos y se superponen.
#
# - `palette`:
#   Especifica la **paleta de colores** a usar para `hue`.
#   Ejemplos: `"deep"`, `"muted"`, `"pastel"`, `"bright"`.
#
# - `data`:
#   El **DataFrame** de Pandas que contiene las variables a graficar.
#
# - `legend`:
#   Controla la leyenda. Puedes usar `"auto"`, `False`, o personalizarla.
#
# - `marker`:
#   Establece manualmente el **símbolo** de los puntos (por ejemplo `'o'`, `'s'`, `'^'`).
