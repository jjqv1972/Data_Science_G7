# %% [markdown]
# # EJERCICIOS USANDO DATASET TITANIC

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el dataset Titanic
titanic = sns.load_dataset("titanic")
titanic.dropna(inplace=True)
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 🧪 Ejercicios de Visualización con Seaborn y el dataset Titanic
#
# ---
#
# ## 📊 Ejercicio 1: Visualización de Distribución con `displot`
#
# **Enunciado:**
# Utiliza `sns.displot` para visualizar la distribución de la variable numérica `age` (edad) de los pasajeros del Titanic.
# Agrega una curva de densidad (`kde=True`) y personaliza el número de intervalos (`bins`) para observar mejor la forma de la distribución.
#
# ---

# %%
sns.displot(data=titanic,x='age',kde=True,bins=20)
plt.title("Distribución de edades de los pasajeros del Titanic")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ## 🔵 Ejercicio 2: Relación entre dos variables numéricas con `scatterplot`
#
# **Enunciado:**
# Crea un gráfico de dispersión usando `sns.scatterplot` para analizar la relación entre `age` (edad) y `fare` (tarifa pagada).
# Utiliza el parámetro `hue` para diferenciar por la variable `sex` y agrega transparencia (`alpha`) para mejorar la visualización.
#
# ---

# %%
sns.scatterplot(data=titanic,x='age',y='fare',hue='sex',alpha=0.6)
plt.show()

# %% [markdown]
# ## 🟢 Ejercicio 3: Comparación categórica con `catplot`
#
# **Enunciado:**
# Usa `sns.catplot` con `kind="count"` para comparar la cantidad de pasajeros según su `class` (Primera, Segunda o Tercera clase), separados por sexo (`hue="sex"`).
# Además, utiliza el parámetro `col="survived"` para mostrar gráficos separados entre los que sobrevivieron y los que no.
#
# ---

# %%
sns.catplot(
    data=titanic,
    x='class',
    hue='sex',
    kind='count',
    col='survived'
)
plt.show()

# %% [markdown]
# ---
#
# ## 🔗 Ejercicio 4: Análisis bivariado con `jointplot`
#
# **Enunciado:**
# Usa `sns.jointplot` para explorar la relación entre `age` (edad) y `fare` (tarifa pagada) por los pasajeros del Titanic.
# Agrega el parámetro `kind="kde"` para visualizar la distribución conjunta como un mapa de densidad suave.
# Puedes ajustar el tamaño del gráfico con `height=6`.
#
# ---

# %%
sns.jointplot(data=titanic,x='age',y='fare',kind='kde',height=6)
plt.show()

# %% [markdown]
# ## 🧩 Ejercicio 5: Matriz de relaciones con `pairplot`
#
# **Enunciado:**
# Crea una matriz de gráficos con `sns.pairplot` para analizar las relaciones entre las variables numéricas:
# `age`, `fare` y `pclass`.
# Usa el parámetro `hue="sex"` para observar cómo varían estas relaciones según el sexo del pasajero.
# Si deseas simplificar la visualización, puedes usar `corner=True`.

# %%
sns.pairplot(data=titanic,vars=['age','fare','pclass'],hue='sex',corner=True)
plt.show()
