# %% [markdown]
# ## ¿Qué es Plotly?
#
# Plotly es una **biblioteca de visualización de datos interactiva** que permite crear gráficos dinámicos y de alta calidad directamente desde lenguajes como **Python**, **R** o **JavaScript**. A diferencia de librerías más tradicionales como Matplotlib, Plotly está pensada desde el inicio para generar gráficos **interactivos**, que el usuario puede explorar con el ratón: hacer zoom, mover, seleccionar, mostrar tooltips, exportar imágenes, etc.
#
# ---
#
# ### Características principales de Plotly
#
# - 🎯 **Interactividad**:
#   Los gráficos permiten:
#   - Hacer zoom y pan (desplazamiento).
#   - Mostrar valores al pasar el cursor (hover).
#   - Activar o desactivar series desde la leyenda.
#   - Guardar la figura como imagen (PNG).
#
# - 🌐 **Basada en la web**:
#   Plotly genera gráficos en formato **HTML/JavaScript** utilizando la librería `plotly.js`.
#   Esto permite:
#   - Incrustar gráficos en páginas web.
#   - Integrar visualizaciones en cuadernos Jupyter, Google Colab, Dash, etc.
#
# - 📊 **Gran variedad de tipos de gráficos**:
#   - Gráficos básicos: líneas, barras, dispersión (scatter), histogramas, boxplot, etc.
#   - Gráficos estadísticos: heatmaps, violin plots, distplots, etc.
#   - Gráficos geográficos: mapas coropléticos, mapas de burbujas, etc.
#   - Gráficos 3D: superficies, scatter 3D, mallas.
#   - Gráficos especializados: Sankey, treemap, sunburst, radar, etc.
#
# - 🎨 **Altamente personalizable**:
#   - Colores, temas, tamaños, fuentes.
#   - Títulos, ejes, anotaciones, formas, imágenes de fondo.
#   - Layouts con subplots y múltiples ejes.

# %%
import plotly
plotly.__version__
# Out:
# '5.24.1'

# %% [markdown]
# # PLOTLY EXPRESS

# %%
import plotly.express as px
df = px.data.tips()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # CREAMOS UN GRAFICO INTERACTIVO CON PLOTLY EXPRESS

# %%
fig = px.scatter(df,x='total_bill',y='tip',color='sex')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
