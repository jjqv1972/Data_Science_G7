# %% [markdown]
# # FUNCIONES MAS COMUNES EN NUMPY

# %%
import numpy as np

# %% [markdown]
# # SHAPE Y RESHAPE

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[5, 8],
#        [9, 5],
#        [4, 2]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.reshape(1,6)
# Out:
# array([[5, 8, 9, 5, 4, 2]])

# %%
arr.ndim
# Out:
# 2

# %% [markdown]
# # MAX Y ARGMAX

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([14, 11,  5,  6,  4, 12, 11, 15, 17,  5])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[14, 11,  5,  6,  4],
#        [12, 11, 15, 17,  5]])

# %%
arr.max()
# Out:
# np.int64(17)

# %%
matriz.max()
# Out:
# np.int64(17)

# %%
arr.argmax()
# Out:
# np.int64(8)

# %%
matriz.argmax()
# Out:
# np.int64(8)

# %% [markdown]
# # MIN Y ARGMIN

# %%
arr.min()
# Out:
# np.int64(4)

# %%
matriz.min()
# Out:
# np.int64(4)

# %%
matriz.min(0)
# Out:
# array([12, 11,  5,  6,  4])

# %%
matriz.min(1)
# Out:
# array([4, 5])

# %% [markdown]
# # SORT

# %%
arr
# Out:
# array([14, 11,  5,  6,  4, 12, 11, 15, 17,  5])

# %%
arr.sort()
arr
# Out:
# array([ 4,  5,  5,  6, 11, 11, 12, 14, 15, 17])

# %%
arr2 = arr[::-1]
arr2
# Out:
# array([17, 15, 14, 12, 11, 11,  6,  5,  5,  4])
