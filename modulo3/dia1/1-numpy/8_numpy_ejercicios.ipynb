# %%
import numpy as np

# %%
temperaturas = np.random.uniform(15,40,30)
temperaturas
# Out:
# array([34.47354413, 29.37783522, 15.78861872, 37.21305334, 19.69310697,
#        19.1884312 , 22.51757131, 39.50643711, 25.41925236, 39.73179612,
#        15.50447633, 23.26498365, 17.52139252, 37.30293727, 36.28029971,
#        29.95148765, 15.22775314, 27.0686489 , 27.65421417, 16.33018114,
#        26.5730949 , 18.99959188, 26.4418883 , 16.68341204, 15.79508008,
#        39.73525713, 23.61174057, 33.2132442 , 39.27343693, 17.70848719])

# %%
matriz_temp = temperaturas.reshape(5,6)
matriz_temp
# Out:
# array([[34.47354413, 29.37783522, 15.78861872, 37.21305334, 19.69310697,
#         19.1884312 ],
#        [22.51757131, 39.50643711, 25.41925236, 39.73179612, 15.50447633,
#         23.26498365],
#        [17.52139252, 37.30293727, 36.28029971, 29.95148765, 15.22775314,
#         27.0686489 ],
#        [27.65421417, 16.33018114, 26.5730949 , 18.99959188, 26.4418883 ,
#         16.68341204],
#        [15.79508008, 39.73525713, 23.61174057, 33.2132442 , 39.27343693,
#         17.70848719]])

# %% [markdown]
# # Encuentra:
# ### - La temperatura máxima por semana
# ### - El día (índice) en que ocurrió la temperatura máxima por semana
# ### - La semana con mayor temperatura global
